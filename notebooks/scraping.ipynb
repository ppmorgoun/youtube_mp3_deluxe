# %%
from bs4 import BeautifulSoup
import requests
import re
import youtube_dl

# %%
link = 'https://www.youtube.com/watch?v=V037zkkQAOI&list=LL&index=1'


response = requests.get(link)
soup = BeautifulSoup(response.text, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-GB" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" typography="" typography-spacing="">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script nonce="f6VKPlYhC+cuWUjbQY2wLQ">
#    var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# window.ytcfg.set('EMERGENCY_BASE_URL', '\/error_204?t\x3djserror\x26level\x3dERROR\x26client.name\x3d1\x26client.version\x3d2.20210630.07.00');
#   </script>
#   <script nonce="f6VKPlYhC+cuWUjbQY2wLQ">
#    (function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;
# ...

# %%
# Get video title
titleSoupMeta = soup.find("meta", property="og:title")
videoTitle = titleSoupMeta["content"] if titleSoupMeta else "NotFound"

print(videoTitle)
# Out:
# EMDI x HVSH - Hideaway (ft. Britt Lari)

# %%
# Video views
# MAKE SURE TO CHECK in other videos that the interaction count == views

videoViews = soup.find(attrs={"itemprop": "interactionCount"}).attrs['content']
print(videoViews)
# Out:
# 2750

# %%
# Other features

videoPublished = soup.find(attrs={"itemprop": "uploadDate"}).attrs['content']
videoCategory = soup.find(attrs={"itemprop": "genre"}).attrs['content']
description = soup.find(attrs={"itemprop": "description"}).attrs['content']
duration = soup.find(attrs={"itemprop": "duration"}).attrs['content']
minutes = re.findall('[0-9]+', duration)[0]
seconds = re.findall('[0-9]+', duration)[1]
returned = [videoViews, videoTitle, videoPublished, videoCategory, description, duration, minutes, seconds]

# %%
for i in returned:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
# Attempting to parse a youtube playlist and return all individual video urls

ydl = youtube_dl.YoutubeDL({'outtmpl': '%(id)s%(ext)s', 'quiet':True,})
video = ""
yt_url = 'https://www.youtube.com/playlist?list=PLjsZNSbnATzruFTYqwP6QjfrGL68wyME7'
with ydl:
    result = ydl.extract_info \
    (yt_url,
    download=False) #We just want to extract the info

    if 'entries' in result:
        # Can be a playlist or a list of videos
        video = result['entries']

        #loops entries to grab each video_url
        for i, item in enumerate(video):
            video = result['entries'][i]
# Out:
# WARNING: unable to download video info webpage: HTTP Error 404: Not Found
# ERROR: Sign in to confirm your age
# This video may be inappropriate for some users.
# ---------------------------------------------------------------------------
# ExtractorError                            Traceback (most recent call last)
# /opt/anaconda3/envs/utube/lib/python3.8/site-packages/youtube_dl-2021.4.26-py3.8.egg/youtube_dl/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     805             try:
# --> 806                 return func(self, *args, **kwargs)
#     807             except GeoRestrictedError as e:
#
# /opt/anaconda3/envs/utube/lib/python3.8/site-packages/youtube_dl-2021.4.26-py3.8.egg/youtube_dl/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#     826     def __extract_info(self, url, ie, download, extra_info, process):
# --> 827         ie_result = ie.extract(url)
# ...

# %%
video
